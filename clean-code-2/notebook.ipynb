# %%
from helpers.local import dice
dice()
# Out:
# This code in run every time we import the file :
#  Importing this file.
#  __name__='helpers.local'
# 5

# %%
from clean_code_2.utils.generate import generate_random_number
generate_random_number()
# Out:
# 86
